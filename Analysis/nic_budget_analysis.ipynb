# %%
from matplotlib import pyplot as plt
from scipy import stats
from scipy.stats import linregress
import numpy as np
import pandas as pd
from pathlib import Path

# %%
#Read in csv and create dataframe
file_path = Path("../Resources/Budget/Budget_by_County_Merged.csv")

df = pd.read_csv(file_path)



df.head()
# Out:
#     State County/ Congressional District  Veteran Population*  \
# 0  Alaska                 ALEUTIANS EAST                  179
# 1  Alaska                 ALEUTIANS WEST                  387
# 2  Alaska                      ANCHORAGE                31274
# 3  Alaska                         BETHEL                 1228
# 4  Alaska                    BRISTOL BAY                  170
#
#    Total Expenditure  Compensation & Pension  Construction  \
# 0                126                      28             0
# 1                179                     122             0
# 2             190835                   81093         13678
# 3                731                     396             0
# 4                311                     190             0
#
#    Education & Vocational Rehabilitation/ Employment  Loan Guaranty#  \
# 0                                                  0               0
# 1                                                  8               0
# 2                                              19025               0
# 3                                                 37               0
# 4                                                  0               0
#
#    General Operating Expenses  Insurance & Indemnities  Medical Care  \
# 0                           0                        0            97
# 1                           0                        0            49
# 2                        6550                     1487         69002
# 3                           0                        0           298
# 4                           0                        9           112
#
#    Unique Patients**  Year
# 0                  9  2010
# 1                 24  2010
# 2               7718  2010
# 3                 61  2010
# 4                 23  2010

# %%
#Clean up column names
df = df.rename(columns={"County/ Congressional District": "County",
                       "Veteran Population*": "Veteran Population",
                       "Loan Guaranty#": "Loan Guaranty"})

# %%
#Drop columns that are required
df = df.drop(["Unique Patients**"], axis=1)

df.head()
# Out:
#     State          County  Veteran Population  Total Expenditure  \
# 0  Alaska  ALEUTIANS EAST                 179                126
# 1  Alaska  ALEUTIANS WEST                 387                179
# 2  Alaska       ANCHORAGE               31274             190835
# 3  Alaska          BETHEL                1228                731
# 4  Alaska     BRISTOL BAY                 170                311
#
#    Compensation & Pension  Construction  \
# 0                      28             0
# 1                     122             0
# 2                   81093         13678
# 3                     396             0
# 4                     190             0
#
#    Education & Vocational Rehabilitation/ Employment  Loan Guaranty  \
# 0                                                  0              0
# 1                                                  8              0
# 2                                              19025              0
# 3                                                 37              0
# 4                                                  0              0
#
#    General Operating Expenses  Insurance & Indemnities  Medical Care  Year
# 0                           0                        0            97  2010
# 1                           0                        0            49  2010
# 2                        6550                     1487         69002  2010
# 3                           0                        0           298  2010
# 4                           0                        9           112  2010

# %%
# multiply columns by thousand to show accurate numbers (before cleaning Xls datasets in excel -
# datasets stated financial numbers were in thousands (,000))

df["Total Expenditure"] = df["Total Expenditure"].mul(1000)
df["Compensation & Pension"] = df["Compensation & Pension"].mul(1000)
df["Construction"] = df["Construction"].mul(1000)
df["Education & Vocational Rehabilitation/ Employment"] = df["Education & Vocational Rehabilitation/ Employment"].mul(1000)
df["Loan Guaranty"] = df["Loan Guaranty"].mul(1000)
df["General Operating Expenses"] = df["General Operating Expenses"].mul(1000)
df['Insurance & Indemnities'] = df["Insurance & Indemnities"].mul(1000)
df['Medical Care'] = df["Medical Care"].mul(1000)

df.head()
# Out:
#     State          County  Veteran Population  Total Expenditure  \
# 0  Alaska  ALEUTIANS EAST                 179             126000
# 1  Alaska  ALEUTIANS WEST                 387             179000
# 2  Alaska       ANCHORAGE               31274          190835000
# 3  Alaska          BETHEL                1228             731000
# 4  Alaska     BRISTOL BAY                 170             311000
#
#    Compensation & Pension  Construction  \
# 0                   28000             0
# 1                  122000             0
# 2                81093000      13678000
# 3                  396000             0
# 4                  190000             0
#
#    Education & Vocational Rehabilitation/ Employment  Loan Guaranty  \
# 0                                                  0              0
# 1                                               8000              0
# 2                                           19025000              0
# 3                                              37000              0
# 4                                                  0              0
#
#    General Operating Expenses  Insurance & Indemnities  Medical Care  Year
# 0                           0                        0         97000  2010
# 1                           0                        0         49000  2010
# 2                     6550000                  1487000      69002000  2010
# 3                           0                        0        298000  2010
# 4                           0                     9000        112000  2010

# %% [markdown]
# ## San Diego Total Expenditure by Year ##
# 2010: 1,437,610,000 \
# 2011: 1,755,045,000 \
# 2012: 1,687,511,000 \
# 2013: 2,028,580,000 \
# 2014: No Data \
# 2015: 2,383,793,000

# %%
san_diego = df.loc[df["County"] == "SAN DIEGO"]

san_diego
# Out:
#             State     County  Veteran Population  Total Expenditure  \
# 222    California  SAN DIEGO              234959         1437610000
# 3258   California  SAN DIEGO              228526         1755045000
# 6666   California  SAN DIEGO              226852         1687511000
# 9888   California  SAN DIEGO              224881         2028580000
# 13109  California  SAN DIEGO              227463         2383793000
#
#        Compensation & Pension  Construction  \
# 222                 627730000       7264000
# 3258                778958000      36062000
# 6666                687540000       6959000
# 9888                843900000       5965000
# 13109              1055348000      22068000
#
#        Education & Vocational Rehabilitation/ Employment  Loan Guaranty  \
# 222                                            291780000              0
# 3258                                           430735000              0
# 6666                                           429945000              0
# 9888                                           487024000              0
# 13109                                          508150000              0
#
#        General Operating Expenses  Insurance & Indemnities  Medical Care  Year
# 222                      50259000                 23530000     437047000  2010
# 3258                     57657000                 23136000     428497000  2011
# 6666                     62339000                 23906000     476823000  2012
# 9888                     65337000                 21727000     604626000  2013
# 13109                    73522000                 21564000     703141000  2015

# %%
expenditure_over_years = plt.plot(san_diego['Year'], san_diego['Total Expenditure'], color="tab:olive", marker = 'o')

plt.title("San Diego Total Expenditure 2010 - 2015")
plt.xlabel("Year")
plt.ylabel("Total Expenditure ($)")
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

plt.savefig("../Output/San_Diego_Total_Expenditure.png")
plt.show()
# Out:
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\4091429889.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %% [markdown]
# ## Top 10 Counties in Total Expenditure
# 1. Cuyahoga, Ohio - 13,322,032,000
# 2. D.C., District of Columbia - 11,537,050,000
# 3. Los Angeles, California - 10,110,937,000
# 4. San Diego, California - 9,292,539,000
# 5. Travis, Texas - 7,750,047,000
# 6. Bexar, Texas - 7,507,264,000
# 7. Maricopa, Arizona - 7,311,961,000
# 8. Cook, Illinois - 6,272,777,000
# 9. Harris, Texas - 5,796,571,000
# 10. Clark, Nevada - 4,949,678,000

# %%
#plotting top 10 expense by county over year.

# Finding top ten
df_expend_sum = df.groupby(["State", "County"])["Total Expenditure"].sum().sort_values(ascending=False)
df_expend_sum = df_expend_sum.head(10)

# Assign state/county to list
df_expend_sum =  [f"{key[1]}, {key[0]}" for key in df_expend_sum.keys()]



# Create a pivot table dataframe with top 10 counties
pivoted = df.loc[[f"{row[1]['County']}, {row[1]['State']}" in df_expend_sum for row in df.iterrows()],
                 ["County", "State", "Total Expenditure", "Year"]]

#merge county and state into one column
pivoted['County'] = pivoted['County'] + ', ' + pivoted['State']

pivoted = pivoted.pivot(index="Year", columns="County", values="Total Expenditure")

pivoted
# Out:
# County  BEXAR, Texas  CLARK, Nevada  COOK, Illinois  CUYAHOGA, Ohio  \
# Year
# 2010      1200895000      884665000      1135962000      2308568000
# 2011      1482381000      890485000      1134721000      2446675000
# 2012      1330251000      873693000      1151572000      2546650000
# 2013      1573026000     1051792000      1362173000      2763705000
# 2015      1920711000     1249043000      1488349000      3256434000
#
# County  DISTRICT OF COLUMBIA, District Of Columbia  HARRIS, Texas  \
# Year
# 2010                                    1940233000      910513000
# 2011                                    2242043000     1028968000
# 2012                                    2099018000     1043887000
# 2013                                    2295599000     1258362000
# 2015                                    2960157000     1554841000
#
# County  LOS ANGELES, California  MARICOPA, Arizona  SAN DIEGO, California  \
# Year
# 2010                 1640877000         1173230000             1437610000
# 2011                 1757027000         1343221000             1755045000
# 2012                 1810193000         1338616000             1687511000
# 2013                 2258286000         1592681000             2028580000
# 2015                 2644554000         1864213000             2383793000
#
# County  TRAVIS, Texas
# Year
# 2010       1088019000
# 2011       1725119000
# 2012       1892928000
# 2013       1759581000
# 2015       1284400000

# %%
#plot 2010 - 2015
ax = pivoted.plot(legend=False, marker = 'o', alpha= 0.8)
ax.figure.legend(loc="upper right", bbox_to_anchor=(1.5,0.895))
ax.set_ylabel("Expenditure ($)")
ax.set_title("Top 10 Counties in Total Expenditure 2010 - 2015")
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
plt.savefig("../Output/Total_Expenditure_2010-2015_Top_10.png")
plt.show()
# Out:
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\2613448272.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %%
# Sum each year's total expediture by county
sum_of_expenditure = pivoted.sum()
expenditure = pd.DataFrame(sum_of_expenditure)
expenditure = expenditure.rename(columns={expenditure.columns[0] : "Sum of Total Expenditure"})

expenditure
# Out:
#                                             Sum of Total Expenditure
# County
# BEXAR, Texas                                              7507264000
# CLARK, Nevada                                             4949678000
# COOK, Illinois                                            6272777000
# CUYAHOGA, Ohio                                           13322032000
# DISTRICT OF COLUMBIA, District Of Columbia               11537050000
# HARRIS, Texas                                             5796571000
# LOS ANGELES, California                                  10110937000
# MARICOPA, Arizona                                         7311961000
# SAN DIEGO, California                                     9292539000
# TRAVIS, Texas                                             7750047000

# %%
plt.bar(expenditure.index, expenditure["Sum of Total Expenditure"], color=['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple',
                                'tab:brown', 'tab:pink', 'tab:grey', 'tab:olive', 'tab:cyan'], align = "center", alpha = 0.8)

plt.title("Top 10 Counties Total Expenditure")
plt.ylabel("Expenditure ($)")
plt.xlabel("County & State")
plt.xticks(expenditure.index, rotation= 45, ha= 'right')
plt.grid()



# format y_ticks
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

plt.savefig("../Output/total_expenditure_top_10.png")
plt.show()
# Out:
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\3048247780.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %% [markdown]
# ## Average Total Expenditure
# The average expenditure in 2010 was 33,716,351.64 \
# The average expenditure in 2011 was 38,130,585.35 \
# The average expenditure in 2012 was 37,369,533.21 \
# The average expenditure in 2013 was 44,340,992.55 \
#                     2014 - No Data \
# The average expenditure in 2015 was 51,912,415.40 \
# The average expenditure over 5 years was 163,939,945.83

# %%
# Create Df for each year (don't have data for 2014)
df_2010 = df.loc[df["Year"] == 2010]
df_2011 = df.loc[df["Year"] == 2011]
df_2012 = df.loc[df["Year"] == 2012]
df_2013 = df.loc[df["Year"] == 2013]
df_2015 = df.loc[df["Year"] == 2015]

# %%
# Find average total expenditure for each year
average_expend_2010 = round(df_2010["Total Expenditure"].mean(), 2)
average_expend_2011 = round(df_2011["Total Expenditure"].mean(), 2)
average_expend_2012 = round(df_2012["Total Expenditure"].mean(), 2)
average_expend_2013 = round(df_2013["Total Expenditure"].mean(), 2)
average_expend_2015 = round(df_2015["Total Expenditure"].mean(), 2)

# Average Total Expenditure over the 5 year period
overall_expend_average = (average_expend_2010 + average_expend_2011 + average_expend_2012
                          + average_expend_2013 + average_expend_2015 /
                          5)

print(f"The average expenditure in 2010 was ${average_expend_2010:,}")
print(f"The average expenditure in 2011 was ${average_expend_2011:,}")
print(f"The average expenditure in 2012 was ${average_expend_2012:,}")
print(f"The average expenditure in 2013 was ${average_expend_2013:,}")
print(f"The average expenditure in 2015 was ${average_expend_2015:,}")
print(f"The average expenditure over 5 years was ${overall_expend_average:,}")
# Out:
# The average expenditure in 2010 was $33,716,351.64
# The average expenditure in 2011 was $38,130,585.35
# The average expenditure in 2012 was $37,369,533.21
# The average expenditure in 2013 was $44,340,992.55
# The average expenditure in 2015 was $51,912,415.4
# The average expenditure over 5 years was $163,939,945.83

# %%
d = {"Average Total Expenditure": [average_expend_2010,
                             average_expend_2011,
                             average_expend_2012,
                             average_expend_2013,
                             average_expend_2015],
    "Year": [2010, 2011, 2012, 2013, 2015]} 
    
i = [0, 1, 2, 3, 4]
average_expend = pd.DataFrame(data= d, index=i)

average_expend
# Out:
#    Average Total Expenditure  Year
# 0                33716351.64  2010
# 1                38130585.35  2011
# 2                37369533.21  2012
# 3                44340992.55  2013
# 4                51912415.40  2015

# %%
average_expend.plot(x="Year", y="Average Total Expenditure", marker = 'o')
plt.title("Average Total Expenditure For All Counties")


#formatting
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
plt.savefig("../Output/Country_Average_Overall_Expenditure.png")
plt.show()
# Out:
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\3418797977.py:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %% [markdown]
# ## Program Totals
#
# Most Expensive program: Compensation & Pension \
# Least Expensive program: Loan Guaranty

# %%
#2010 program costs
Comp_2010 = df_2010["Compensation & Pension"].sum()
construct_2010 = df_2010["Construction"].sum()
Education_2010 = df_2010["Education & Vocational Rehabilitation/ Employment"].sum()
Loan_2010 = df_2010["Loan Guaranty"].sum()
Operating_2010 = df_2010["General Operating Expenses"].sum()
Insurance_2010 = df_2010["Insurance & Indemnities"].sum()
Medical_2010 = df_2010["Medical Care"].sum()

#2011 program costs
Comp_2011 = df_2011["Compensation & Pension"].sum()
construct_2011 = df_2011["Construction"].sum()
Education_2011 = df_2011["Education & Vocational Rehabilitation/ Employment"].sum()
Loan_2011 = df_2011["Loan Guaranty"].sum()
Operating_2011 = df_2011["General Operating Expenses"].sum()
Insurance_2011 = df_2011["Insurance & Indemnities"].sum()
Medical_2011 = df_2011["Medical Care"].sum()

#2012 program costs
Comp_2012 = df_2012["Compensation & Pension"].sum()
construct_2012 = df_2012["Construction"].sum()
Education_2012 = df_2012["Education & Vocational Rehabilitation/ Employment"].sum()
Loan_2012 = df_2012["Loan Guaranty"].sum()
Operating_2012 = df_2012["General Operating Expenses"].sum()
Insurance_2012 = df_2012["Insurance & Indemnities"].sum()
Medical_2012 = df_2012["Medical Care"].sum()

#2013 program costs
Comp_2013 = df_2013["Compensation & Pension"].sum()
construct_2013 = df_2013["Construction"].sum()
Education_2013 = df_2013["Education & Vocational Rehabilitation/ Employment"].sum()
Loan_2013 = df_2013["Loan Guaranty"].sum()
Operating_2013 = df_2013["General Operating Expenses"].sum()
Insurance_2013 = df_2013["Insurance & Indemnities"].sum()
Medical_2013 = df_2013["Medical Care"].sum()

#2015 program costs
Comp_2015 = df_2015["Compensation & Pension"].sum()
construct_2015 = df_2015["Construction"].sum()
Education_2015 = df_2015["Education & Vocational Rehabilitation/ Employment"].sum()
Loan_2015 = df_2015["Loan Guaranty"].sum()
Operating_2015 = df_2015["General Operating Expenses"].sum()
Insurance_2015 = df_2015["Insurance & Indemnities"].sum()
Medical_2015 = df_2015["Medical Care"].sum()

# %%
d = {
    "2010": [Comp_2010,construct_2010,Education_2010,Loan_2010,Operating_2010,Insurance_2010,Medical_2010],
    "2011": [Comp_2011,construct_2011,Education_2011,Loan_2011,Operating_2011,Insurance_2011,Medical_2011],
    "2012": [Comp_2012,construct_2012,Education_2012,Loan_2012,Operating_2012,Insurance_2012,Medical_2012],
    "2013": [Comp_2013,construct_2013,Education_2013,Loan_2013,Operating_2013,Insurance_2013,Medical_2013],
    "2015": [Comp_2015,construct_2015,Education_2015,Loan_2015,Operating_2015,Insurance_2015,Medical_2015]
}


i = ["Compensation & Pension", "Construction", "Education & Vocational Rehabilitation/ Employment",
    "Loan Guaranty", "General Operating Expenses", "Insurance & Indemnities", "Medical Care"]

totals = pd.DataFrame(d, i)


totals
# Out:
#                                                           2010         2011  \
# Compensation & Pension                             47784630000  57596479000
# Construction                                        1618835000   1813313000
# Education & Vocational Rehabilitation/ Employment   8260092000  10630399000
# Loan Guaranty                                        804064000   1391866000
# General Operating Expenses                          6100624000   6652415000
# Insurance & Indemnities                             1694238000   1687514000
# Medical Care                                       42371607000  43084780000
#
#                                                           2012         2013  \
# Compensation & Pension                             53243133000  63574729000
# Construction                                        1538320000   1330056000
# Education & Vocational Rehabilitation/ Employment  10424646000  11949185000
# Loan Guaranty                                       1588712000   1385063000
# General Operating Expenses                          6444580000   6889918000
# Insurance & Indemnities                             1643976000   1699602000
# Medical Care                                       45521300000  55993794000
#
#                                                           2015
# Compensation & Pension                             75787362000
# Construction                                        1827764000
# Education & Vocational Rehabilitation/ Employment  13408405000
# Loan Guaranty                                        865419000
# General Operating Expenses                          8055571000
# Insurance & Indemnities                             1704548000
# Medical Care                                       65560844000

# %%
ax = totals.plot.bar()
ax.set_title("Program Expenditure Per Year")
ax.set_ylabel("Expenditure ($)")
ax.set_xlabel("VA Program")
ax.set_xticklabels(totals.index, rotation= 45, ha= 'right')


#formatting
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
plt.grid()
plt.savefig("../Output/Program_Expenditure_Per_Year.png")
plt.show()
# Out:
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\3852726063.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %% [markdown]
# ## Average per Program

# %%
#2010 program average
comp_average_2010 = df_2010["Compensation & Pension"].mean()
construct_average_2010 = df_2010["Construction"].mean()
education_average_2010 = df_2010["Education & Vocational Rehabilitation/ Employment"].mean()
loan_average_2010 = df_2010["Loan Guaranty"].mean()
Operating_average_2010 = df_2010["General Operating Expenses"].mean()
Insurance_average_2010 = df_2010["Insurance & Indemnities"].mean()
Medical_average_2010 = df_2010["Medical Care"].mean()

#2011 program average
comp_average_2011 = df_2011["Compensation & Pension"].mean()
construct_average_2011 = df_2011["Construction"].mean()
education_average_2011 = df_2011["Education & Vocational Rehabilitation/ Employment"].mean()
loan_average_2011 = df_2011["Loan Guaranty"].mean()
Operating_average_2011 = df_2011["General Operating Expenses"].mean()
Insurance_average_2011 = df_2011["Insurance & Indemnities"].mean()
Medical_average_2011 = df_2011["Medical Care"].mean()

#2012 program average
comp_average_2012 = df_2012["Compensation & Pension"].mean()
construct_average_2012 = df_2012["Construction"].mean()
education_average_2012 = df_2012["Education & Vocational Rehabilitation/ Employment"].mean()
loan_average_2012 = df_2012["Loan Guaranty"].mean()
Operating_average_2012 = df_2012["General Operating Expenses"].mean()
Insurance_average_2012 = df_2012["Insurance & Indemnities"].mean()
Medical_average_2012 = df_2012["Medical Care"].mean()

#2013 program average
comp_average_2013 = df_2013["Compensation & Pension"].mean()
construct_average_2013 = df_2013["Construction"].mean()
education_average_2013 = df_2013["Education & Vocational Rehabilitation/ Employment"].mean()
loan_average_2013 = df_2013["Loan Guaranty"].mean()
Operating_average_2013 = df_2013["General Operating Expenses"].mean()
Insurance_average_2013 = df_2013["Insurance & Indemnities"].mean()
Medical_average_2013 = df_2013["Medical Care"].mean()

#2015 program average
comp_average_2015 = df_2015["Compensation & Pension"].mean()
construct_average_2015 = df_2015["Construction"].mean()
education_average_2015 = df_2015["Education & Vocational Rehabilitation/ Employment"].mean()
loan_average_2015 = df_2015["Loan Guaranty"].mean()
Operating_average_2015 = df_2015["General Operating Expenses"].mean()
Insurance_average_2015 = df_2015["Insurance & Indemnities"].mean()
Medical_average_2015 = df_2015["Medical Care"].mean()

# %%
d = {
    "Compensation & Pension": [comp_average_2010, comp_average_2011,
                               comp_average_2012,comp_average_2013, comp_average_2015],
    
    "Construction": [construct_average_2010, construct_average_2011, 
                     construct_average_2012, construct_average_2013, construct_average_2015],
    
    "Education": [education_average_2010, education_average_2011, 
                  education_average_2012, education_average_2013, education_average_2015],
    
    "Loan Guaranty": [loan_average_2010, loan_average_2011, 
                      loan_average_2012, loan_average_2013, loan_average_2015],
    
     "Operating Expenses": [Operating_average_2010, Operating_average_2011, 
                            Operating_average_2012, Operating_average_2013, Operating_average_2015],
    
     "Insurance": [Insurance_average_2010, Insurance_average_2011, 
                   Insurance_average_2012, Insurance_average_2013, Insurance_average_2015],
    
     "Medical": [Medical_average_2010, Medical_average_2011, 
                 Medical_average_2012, Medical_average_2013, Medical_average_2015]
    }

i = [2010, 2011, 2012, 2013, 2015]

averages = pd.DataFrame(d, i)

averages
# Out:
#       Compensation & Pension   Construction     Education  Loan Guaranty  \
# 2010            1.483074e+07  502431.719429  2.563654e+06  249554.314091
# 2011            1.787600e+07  562791.123526  3.299317e+06  431988.206083
# 2012            1.652487e+07  477442.582247  3.235458e+06  493082.557418
# 2013            1.973757e+07  412932.629618  3.709775e+06  430010.245265
# 2015            2.352914e+07  567452.343993  4.162808e+06  268680.223533
#
#       Operating Expenses      Insurance       Medical
# 2010        1.893428e+06  525834.264432  1.315072e+07
# 2011        2.064685e+06  523747.361887  1.337206e+07
# 2012        2.000180e+06  510234.636872  1.412827e+07
# 2013        2.139062e+06  527662.837628  1.738398e+07
# 2015        2.500953e+06  529198.385595  2.035419e+07

# %%
ax = averages.plot(alpha=0.8, legend=False, marker = 'o')

ax.figure.legend(loc="upper right", bbox_to_anchor=(1.3,0.895))
ax.set_title("Program Average Expenditure Per Year")
ax.set_ylabel("Expenditure ($)")
ax.set_xlabel("Year")

#formatting
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
plt.grid()
plt.savefig("../Output/Program_Expenditure_Per_Year.png")
plt.show()
# Out:
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\2023483394.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %% [markdown]
# ## VA Yearly Expenses
#
# 2010: 108,634,090,000 \
# 2011: 122,856,766,000 \
# 2012: 120,404,667,000 \
# 2013: 142,822,347,000 \
# 2014: No Data \
# 2015: 167,209,913,000

# %%
# Total VA Expenses per year
totals.sum()
# Out:
# 2010    108634090000
# 2011    122856766000
# 2012    120404667000
# 2013    142822347000
# 2015    167209913000
# dtype: int64

# %%
ax = totals.sum().plot(kind='bar', color=['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple'], alpha= 0.8)

ax.set_title("Veterans Affairs Expenditure Per Year")
ax.set_ylabel("Expenditure ($)")
ax.set_xlabel("Year")
ax.set_xticklabels(totals.sum().index, rotation= 45, ha= 'right')

#formatting
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
plt.grid()
plt.savefig("../Output/VA_Expenditure_Per_Year.png")
plt.show()
# Out:
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\1608700980.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %% [markdown]
# ## Trend in Compensation Users and Funding

# %%
#Read in csv and create dataframe
file_path = Path("../Resources/Programs/Users_by_Program__2010_2021.csv")

program_user_df = pd.read_csv(file_path)

#Getting the years required for comparision
program_user_df = program_user_df.head(6)

# Remove 2014 as we don't have budget data for 2014
program_user_df = program_user_df.loc[program_user_df["Year"] != 2014]

# Remove columns that we don't need
program_user_df = program_user_df.drop(["Vocational Rehabilitation", 
                                       "Memorial Benefits", 
                                       "Education", 
                                       "Life Insurance", 
                                       "Home Loan Guaranty", 
                                       "Health Care"], axis=1)

program_user_df
# Out:
#    Year  Compensation or Pension
# 0  2010                  3506633
# 1  2011                  3642258
# 2  2012                  3825350
# 3  2013                  4025539
# 5  2015                  4435146

# %%
x_values = program_user_df['Year']
y_values = program_user_df['Compensation or Pension']

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r--")
plt.annotate(line_eq,(0.05,0.8), xycoords = "axes fraction",fontsize=15,color="red")
plt.title("Compensation or Pension Users 2010-2015")
plt.xlabel('Year')
plt.ylabel('Number of Compensation or Pension Users')
print(f"The P-Value is {pvalue}")



#formatting
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
plt.grid()
plt.savefig("../Output/Compensation_User_Linear_Regression.png")
plt.show()
# Out:
# The P-Value is 0.00015200437943290306
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\466170073.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])

# %%
d = {"Year": program_user_df["Year"],
    "Compensation or Pension": [Comp_2010, Comp_2011, Comp_2012, Comp_2013, Comp_2015]}



comp_totals = pd.DataFrame(d)

comp_totals
# Out:
#    Year  Compensation or Pension
# 0  2010              47784630000
# 1  2011              57596479000
# 2  2012              53243133000
# 3  2013              63574729000
# 5  2015              75787362000

# %%
x_values = comp_totals["Year"]
y_values = comp_totals["Compensation or Pension"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r--")
plt.annotate(line_eq,(0.2,0.1), xycoords = "axes fraction",fontsize=15,color="red")
plt.title("Compensation or Pension Total Expenditure 2010 - 2015")
plt.xlabel('Year')
plt.ylabel('Expenditure ($)')
print(f"The P-Value is {pvalue}")



#formatting
current_values = plt.gca().get_yticks()
plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
plt.grid()
plt.savefig("../Output/Compensation_Linear Regression.png")
plt.show()
# Out:
# The P-Value is 0.015133584514897791
# C:\Users\nicdu\AppData\Local\Temp\ipykernel_6676\3756556926.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_yticklabels(['{:,.0f}'.format(x) for x in current_values])
